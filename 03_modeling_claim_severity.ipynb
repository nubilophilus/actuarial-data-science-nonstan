# %% [markdown]
# # Claim Severity Modeling
#
# Train and review the claim severity workflow.

# %%
import sys
from pathlib import Path

base_dir = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(base_dir) not in sys.path:
    sys.path.insert(0, str(base_dir))

from src.data_ingestion import load_datasets
from src.data_cleaning import clean_datasets
from src.feature_engineering import build_analytical_base_table
from src.modeling_severity import train_claim_severity_model

abt = build_analytical_base_table(clean_datasets(load_datasets()))
results = train_claim_severity_model(abt)
results['metrics']
